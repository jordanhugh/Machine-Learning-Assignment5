# %%
# %run Assignment5.py
# Out:
# KRR Parameter Table:
# Parameter(γ)  Parameter(θ)
# 0             array([-0.57142857,  1.42857143, -0.57142857])
# 1             array([-0.18331618,  0.75658434, -0.18331618])
# 5             array([-0.00299476,  0.66669357, -0.00299476])
# 10            array([-2.01777466e-05,  6.66666668e-01, -2.01777466e-05])
# 25            array([-6.17241950e-12,  6.66666667e-01, -6.17241950e-12])
# KRR Penalty Parameter Table:
# Penalty(C)  Parameter(θ)
# 0.1         array([-0.00018717,  0.16666709, -0.00018717])
# 1           array([-0.00299476,  0.66669357, -0.00299476])
# 1000        array([-0.00673182,  0.99959092, -0.00673182])
# Optimal Value: 10
# Optimal Value: 1
# Optimal Value: 5
# Evaluation:
# Classifier   MSE        STD
# kNN          0.100757   0.009417
# KRR          0.083027   0.005799
# Dummy        1.001041   0.081032
