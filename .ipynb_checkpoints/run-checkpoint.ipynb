# %%
# %run Assignment5.py
# Out:
# KRR Parameter Table:
# Parameter(γ)  Parameter(θ)
# 0             array([-0.25,  0.75, -0.25])
# 1             array([-0.09768542,  0.53593646, -0.09768542])
# 5             array([-0.00168452,  0.50001135, -0.00168452])
# 10            array([-1.13499825e-05,  5.00000001e-01, -1.13499825e-05])
# 25            array([-3.47198597e-12,  5.00000000e-01, -3.47198597e-12])
# KRR Penalty Parameter Table:
# Penalty(C)  Parameter(θ)
# 0.1         array([-0.00018717,  0.16666709, -0.00018717])
# 1           array([-0.00299476,  0.66669357, -0.00299476])
# 1000        array([-0.00673182,  0.99959092, -0.00673182])
# Optimal Value: 1
# Optimal Value: 5
# Optimal Value: 25
